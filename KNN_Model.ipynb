# %%
'''
'''
import sklearn
from sklearn.utils import shuffle
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
from sklearn import linear_model, preprocessing
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Social_Network_Ads.csv')
print(dataset.head())
dataset.shape
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0
# (400, 3)

# %%
z=list(dataset['Age'])
w=list(dataset['EstimatedSalary'])

# %%
X = list(zip(z,w))
y = list(dataset['Purchased'])
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.1)
Model = KNeighborsClassifier(n_neighbors=11)
Model.fit(x_train, y_train)
accuracy = Model.score(x_test, y_test)
print("Model has",(accuracy*100),'% Accuracy')
# Out:
# Model has 90.0 % Accuracy

# %%
predictions = Model.predict(x_test)
for i in range(len(predictions)):
    print("Model Predicted Purchased: ",predictions[i]," Actual Purchased : ",y_test[i])
# Out:
# Model Predicted Purchased:  0  Actual Purchased :  0
# Model Predicted Purchased:  0  Actual Purchased :  0
# Model Predicted Purchased:  0  Actual Purchased :  0
# Model Predicted Purchased:  0  Actual Purchased :  0
# Model Predicted Purchased:  1  Actual Purchased :  1
# Model Predicted Purchased:  0  Actual Purchased :  0
# Model Predicted Purchased:  0  Actual Purchased :  0
# Model Predicted Purchased:  0  Actual Purchased :  0
# Model Predicted Purchased:  0  Actual Purchased :  0
# Model Predicted Purchased:  1  Actual Purchased :  0
# Model Predicted Purchased:  1  Actual Purchased :  0
# Model Predicted Purchased:  0  Actual Purchased :  0
# Model Predicted Purchased:  0  Actual Purchased :  0
# Model Predicted Purchased:  0  Actual Purchased :  0
# Model Predicted Purchased:  0  Actual Purchased :  0
# Model Predicted Purchased:  0  Actual Purchased :  0
# Model Predicted Purchased:  1  Actual Purchased :  1
# Model Predicted Purchased:  0  Actual Purchased :  0
# ...

# %%
plt.scatter(dataset['Age'],dataset['EstimatedSalary'])
plt.xlabel("Age")
plt.ylabel("Estimated Salary")
plt.show()
